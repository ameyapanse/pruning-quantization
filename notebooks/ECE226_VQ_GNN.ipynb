# %%
# !apt-get install python3.9
# !ln -sf /usr/bin/python3.9 /usr/bin/python3
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libpython3.9-minimal libpython3.9-stdlib python3.9-minimal
# Suggested packages:
#   python3.9-venv binfmt-support
# The following NEW packages will be installed:
#   libpython3.9-minimal libpython3.9-stdlib python3.9 python3.9-minimal
# 0 upgraded, 4 newly installed, 0 to remove and 46 not upgraded.
# Need to get 5,030 kB of archives.
# After this operation, 19.7 MB of additional disk space will be used.
# Get:1 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal/main amd64 libpython3.9-minimal amd64 3.9.17-1+focal1 [805 kB]
# Get:2 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal/main amd64 python3.9-minimal amd64 3.9.17-1+focal1 [2,064 kB]
# Get:3 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal/main amd64 libpython3.9-stdlib amd64 3.9.17-1+focal1 [1,666 kB]
# ...

# %%
# %cp -r /content/drive/MyDrive/ECE\ 226/FinalProject/vq_gnn_v2 .

# %%
# !python --version
# Out:
# Python 3.9.17

# %%
# %rm -rf vq_gnn_v2/

# %%
# %cp -r /content/drive/MyDrive/ECE226/VQ-GNN-main/vq_gnn_v2 .

# %%
# !pip install torch==1.9.1+cu102 torchvision==0.10.1+cu102 torchaudio==0.9.0 -f https://download.pytorch.org/whl/torch_stable.htmlimport
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/torch_stable.htmlimport
# ERROR: Could not find a version that satisfies the requirement torch==1.9.1+cu102 (from versions: 1.11.0, 1.12.0, 1.12.1, 1.13.0, 1.13.1, 2.0.0, 2.0.1)
# ERROR: No matching distribution found for torch==1.9.1+cu102

# %%
import torch
torch.__version__
# Out:
# '2.0.1+cu118'

# %%
# !pip install torch-geometric==1.7.2 \
  torch-sparse \
  torch-scatter \
  torch-cluster \
  -f https://pytorch-geometric.com/whl/torch-1.11.0+cu102.html
# !pip install ogb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://pytorch-geometric.com/whl/torch-1.11.0+cu102.html
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# %cd vq_gnn_v2
# Out:
# [Errno 2] No such file or directory: 'vq_gnn_v2'
# /content/vq_gnn_v2

# %%
#GCN Arxiv Dataset
# !python main_node.py --num-D 4 --conv-type GCN --dataset arxiv --num-parts 80 --batch-size 40 --test-batch-size 40 --lr 1e-3 --sampler-type cluster
# Out:
# Namespace(no_second_fc=True, EMA=True, split=True, log_steps=1, runs=1, cluster='vq', ln_para=False, kmeans_init=False, kmeans_iter=100, dropbranch=0.0, weight_ahead=False, skip=False, commitment_cost=0.0, num_branch=0, ce_only=False, sche=False, use_gcn=False, data_root='/cmlscratch/kong/datasets', device=0, num_layers=3, hidden_channels=128, dropout=0, lr=0.001, epochs=500, batch_size=40, test_batch_size=40, num_M=256, num_D=4, grad_scale=[1, 1], act='leaky_gelu', bn_flag=True, warm_up=True, warm_up_epochs=0, momentum=0.1, conv_type='GCN', transformer_flag=False, clip=None, dataset='arxiv', alpha_dropout_flag=False, num_workers=0, sampler_type='cluster', num_parts=80, recovery_flag=True, walk_length=5, cont_sliding_window=1, exp_name='test', exp=False, exp_tag='exp', run_idx=None)
# ...
# Downloaded 0.08 GB: 100% 81/81 [02:37<00:00,  1.94s/it]
# Extracting /cmlscratch/kong/datasets/ogb/arxiv.zip
# Processing...
# Loading necessary files...
# This might take a while.
# ...

# %%
#GCN PPI Dataset
# !python main_node.py --hidden-channels 256  --lr 3e-3 --epochs 5000 --batch-size 30000 --test-batch-size 0 --num-M 4096 --num-D 4  --conv-type GCN --sampler-type node --dataset ppi --skip
# Out:
# Streaming output truncated to the last 5000 lines.
# num_B_prime:27253, new edges:0
# Batch 1.0, train acc:0.9630517129905283
# num_B_prime:0, new edges:0
# num_B_prime:0, new edges:0
# num_B_prime:0, new edges:0
# Run: 1, Epoch: 4377, Loss: 0.0639, Loss Cls: 0.0639, Train: 96.30%, Valid: 93.40%, Test: 95.24%
# num_B_prime:14514, new edges:0
# Batch 0.0, train acc:0.9644597498489738
# num_B_prime:27283, new edges:0
# Batch 1.0, train acc:0.964390450561406
# num_B_prime:0, new edges:0
# num_B_prime:0, new edges:0
# num_B_prime:0, new edges:0
# Run: 1, Epoch: 4378, Loss: 0.0607, Loss Cls: 0.0607, Train: 96.42%, Valid: 93.52%, Test: 95.32%
# num_B_prime:14511, new edges:0
# Batch 0.0, train acc:0.9658456816319462
# num_B_prime:27281, new edges:0
# Batch 1.0, train acc:0.9626039730138357
# num_B_prime:0, new edges:0
# num_B_prime:0, new edges:0
# num_B_prime:0, new edges:0
# Run: 1, Epoch: 4379, Loss: 0.0608, Loss Cls: 0.0608, Train: 96.47%, Valid: 93.52%, Test: 95.36%
# ...

# %%
#GAT PPI Dataset No improvements, used torch-geometric GAT
# !python main_node.py --hidden-channels 256  --lr 3e-3 --epochs 5000 --batch-size 20000 --test-batch-size 0 --num-M 4096 --num-D 4  --conv-type GAT --sampler-type node --dataset ppi --skip
# Out:
# Namespace(no_second_fc=True, EMA=True, split=True, log_steps=1, runs=1, cluster='vq', ln_para=False, kmeans_init=False, kmeans_iter=100, dropbranch=0.0, weight_ahead=False, skip=True, commitment_cost=0.0, num_branch=0, ce_only=False, sche=False, use_gcn=False, data_root='/cmlscratch/kong/datasets', device=0, num_layers=3, hidden_channels=256, dropout=0, lr=0.003, epochs=5000, batch_size=20000, test_batch_size=0, num_M=4096, num_D=4, grad_scale=[1, 1], act='leaky_gelu', bn_flag=True, warm_up=True, warm_up_epochs=0, momentum=0.1, conv_type='GAT', transformer_flag=False, clip=None, dataset='ppi', alpha_dropout_flag=False, num_workers=0, sampler_type='node', num_parts=1, recovery_flag=True, walk_length=5, cont_sliding_window=1, exp_name='test', exp=False, exp_tag='exp', run_idx=None)
# PPI loaded
# 1
# num_B_prime:0, new edges:0
# 2324.70528
# 2
# num_B_prime:0, new edges:0
# 2946.749952
# 3
# num_B_prime:0, new edges:0
# 2993.563136
# init done
# num_B_prime:23457, new edges:0
# ...

# %%
# !python main_node.py --hidden-channels 256  --lr 3e-3 --epochs 5000 --batch-size 20000 --test-batch-size 0 --num-M 4096 --num-D 4  --conv-type GAT --sampler-type node --dataset ppi --skip
# Out:
# Namespace(no_second_fc=True, EMA=True, split=True, log_steps=1, runs=1, cluster='vq', ln_para=False, kmeans_init=False, kmeans_iter=100, dropbranch=0.0, weight_ahead=False, skip=True, commitment_cost=0.0, num_branch=0, ce_only=False, sche=False, use_gcn=False, data_root='/cmlscratch/kong/datasets', device=0, num_layers=3, hidden_channels=256, dropout=0, lr=0.003, epochs=5000, batch_size=20000, test_batch_size=0, num_M=4096, num_D=4, grad_scale=[1, 1], act='leaky_gelu', bn_flag=True, warm_up=True, warm_up_epochs=0, momentum=0.1, conv_type='GAT', transformer_flag=False, clip=None, dataset='ppi', alpha_dropout_flag=False, num_workers=0, sampler_type='node', num_parts=1, recovery_flag=True, walk_length=5, cont_sliding_window=1, exp_name='test', exp=False, exp_tag='exp', run_idx=None)
# PPI loaded
# 1
# num_B_prime:0, new edges:0
# Traceback (most recent call last):
#   File "/content/vq_gnn_v2/main_node.py", line 311, in <module>
#     main()
# ...

# %%
# !python main_node.py --hidden-channels 256  --lr 3e-3 --epochs 5000 --batch-size 20000 --test-batch-size 0 --num-M 4096 --num-D 4  --conv-type GAT --sampler-type node --dataset ppi --skip
# Out:
# terminate called after throwing an instance of 'std::bad_alloc'
#   what():  std::bad_alloc
