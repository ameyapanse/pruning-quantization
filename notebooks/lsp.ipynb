# %%
# %cd /content/drive/MyDrive      /GNN_experiments-main
# Out:
# /content/drive/MyDrive/GNN_experiments-main

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install --upgrade setuptools
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 18.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 67.7.2
#     Uninstalling setuptools-67.7.2:
#       Successfully uninstalled setuptools-67.7.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# ...

# %%
# !pip install -r requirments.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 23.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 9.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.2/224.2 kB 22.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 106.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 593.7/593.7 kB 53.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 74.0 MB/s eta 0:00:00
# ...
#   Created wheel for data: filename=data-0.4-py3-none-any.whl size=7227 sha256=867f9eaef609ee7ecbe987a151349114d941dc169ea46417077221ce6ba94260
#   Stored in directory: /root/.cache/pip/wheels/d0/e8/fa/e253c256048ea58d99a8abb5e751abb6a838af6f12887b5418
# ...

# %%
# !pip install torch-geometric \
  torch-sparse \
  torch-scatter \
  torch-cluster \
  -f https://pytorch-geometric.com/whl/torch-2.0.1+cu118.html
# !pip install ogb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://pytorch-geometric.com/whl/torch-2.0.1+cu118.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 661.6/661.6 kB 14.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 60.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 64.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 40.0 MB/s eta 0:00:00
# ...
#   Created wheel for torch-geometric: filename=torch_geometric-2.3.1-py3-none-any.whl size=910459 sha256=5ffc20dcef557bb56aeb6dd38fe5816a90e94a4f9328493075575db8b8eb7980
#   Stored in directory: /root/.cache/pip/wheels/ac/dc/30/e2874821ff308ee67dcd7a66dbde912411e19e35a1addda028
# Successfully built torch-geometric
# ...

# %%
# !python -m tst.ogb.main_with_pruning_node_prediction_on_ppi --pruning_method minhash_lsh_thresholding --device cuda:0 \
 --num_of_epochs 75
# Out:
# 2023-06-08 08:50:35.440592: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-08 08:50:36.482784: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading train graph 1 to CPU. It has 1767 nodes and 34085 edges.
# Loading train graph 2 to CPU. It has 1377 nodes and 31081 edges.
# Loading train graph 3 to CPU. It has 2263 nodes and 61907 edges.
# Loading train graph 4 to CPU. It has 2339 nodes and 67769 edges.
# Loading train graph 5 to CPU. It has 1578 nodes and 37740 edges.
# Loading train graph 6 to CPU. It has 1021 nodes and 19237 edges.
# Loading train graph 7 to CPU. It has 1823 nodes and 46153 edges.
# Loading train graph 8 to CPU. It has 2488 nodes and 72878 edges.
# ...

# %%
# !python -m tst.ogb.main_with_pruning_node_prediction_on_ppi --pruning_method minhash_lsh_thresholding --device cuda:0 \
 --num_of_epochs 100 --num_minhash_funcs 15
# Out:
# 2023-06-08 09:10:26.177849: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-08 09:10:27.221192: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading train graph 1 to CPU. It has 1767 nodes and 34085 edges.
# Loading train graph 2 to CPU. It has 1377 nodes and 31081 edges.
# Loading train graph 3 to CPU. It has 2263 nodes and 61907 edges.
# Loading train graph 4 to CPU. It has 2339 nodes and 67769 edges.
# Loading train graph 5 to CPU. It has 1578 nodes and 37740 edges.
# Loading train graph 6 to CPU. It has 1021 nodes and 19237 edges.
# Loading train graph 7 to CPU. It has 1823 nodes and 46153 edges.
# Loading train graph 8 to CPU. It has 2488 nodes and 72878 edges.
# ...

# %%
# !python -m tst.ogb.main_with_pruning_node_prediction_on_ppi --pruning_method minhash_lsh_thresholding --device cuda:0 \
 --num_of_epochs 1000 --num_minhash_funcs 5
# Out:
# 2023-06-08 10:06:28.068215: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/tensorboard/compat/__init__.py", line 42, in tf
#     from tensorboard.compat import notf  # noqa: F401
# ImportError: cannot import name 'notf' from 'tensorboard.compat' (/usr/local/lib/python3.10/dist-packages/tensorboard/compat/__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 674, in _load_unlocked
# ...

# %%
# !python -m tst.ogb.main_with_pruning_node_prediction_on_ppi --pruning_method minhash_lsh_thresholding --device cuda:0 \
 --num_of_epochs 1000 --num_minhash_funcs 3
# Out:
# 2023-06-08 13:21:17.949454: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-08 13:21:19.660607: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading train graph 1 to CPU. It has 1767 nodes and 34085 edges.
# Loading train graph 2 to CPU. It has 1377 nodes and 31081 edges.
# Loading train graph 3 to CPU. It has 2263 nodes and 61907 edges.
# Loading train graph 4 to CPU. It has 2339 nodes and 67769 edges.
# Loading train graph 5 to CPU. It has 1578 nodes and 37740 edges.
# Loading train graph 6 to CPU. It has 1021 nodes and 19237 edges.
# Loading train graph 7 to CPU. It has 1823 nodes and 46153 edges.
# Loading train graph 8 to CPU. It has 2488 nodes and 72878 edges.
# ...

# %%
# !python -m tst.ogb.main_with_pruning_node_prediction --dataset ppi --gnn gcn --pruning_method minhash_lsh_thresholding --device 0
# Out:
# 2023-06-08 13:57:44.547764: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-08 13:57:45.737453: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Getting dataset...
# /usr/local/lib/python3.10/dist-packages/torch_geometric/data/in_memory_dataset.py:157: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
# Dataset ready!
# lsh_nodes:
# din=50
# num_functions=1
# ...

# %%
# !python -m tst.ogb.main_with_pruning_node_prediction --dataset Cora --gnn gcn --pruning_method minhash_lsh_thresholding --device 0
# Out:
# 2023-06-08 16:22:48.491718: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-08 16:22:49.406260: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Getting dataset...
# Dataset ready!
# /usr/local/lib/python3.10/dist-packages/torch_geometric/data/in_memory_dataset.py:157: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
# lsh_nodes:
# din=1433
# num_functions=1
# ...

# %%
# !python -m tst.ogb.main_with_pruning_node_prediction --dataset Cora --gnn gcn --pruning_method minhash_lsh_thresholding --device 0 \
--num_minhash_funcs 3
# Out:
# 2023-06-08 16:23:29.462534: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-08 16:23:30.374736: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Getting dataset...
# Dataset ready!
# /usr/local/lib/python3.10/dist-packages/torch_geometric/data/in_memory_dataset.py:157: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
# lsh_nodes:
# din=1433
# num_functions=3
# ...

# %%
# !python -m tst.ogb.main_with_pruning_node_prediction --dataset Cora --gnn gcn --pruning_method minhash_lsh_thresholding --device 0 \
--num_minhash_funcs 8
# Out:
# 2023-06-08 16:23:48.344033: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-08 16:23:49.264595: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Getting dataset...
# Dataset ready!
# /usr/local/lib/python3.10/dist-packages/torch_geometric/data/in_memory_dataset.py:157: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
# lsh_nodes:
# din=1433
# num_functions=8
# ...

# %%
# !python -m tst.ogb.main_with_pruning_node_prediction --dataset CiteSeer --gnn sage --pruning_method minhash_lsh_thresholding --device 0 \
--num_minhash_funcs 8
# Out:
# 2023-06-08 16:27:51.654471: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-08 16:27:52.562147: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Getting dataset...
# ...
# Processing...
# Done!
# Dataset ready!
# /usr/local/lib/python3.10/dist-packages/torch_geometric/data/in_memory_dataset.py:157: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
# lsh_nodes:
# din=3703
# ...

# %%
# !python -m tst.ogb.main_with_pruning_node_prediction --dataset Cora --gnn gcn --pruning_method minhash_lsh_thresholding --device 0 \
--num_minhash_funcs 1 --epochs 50
# Out:
# 2023-06-08 16:33:57.125366: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-08 16:33:58.047078: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Getting dataset...
# Dataset ready!
# /usr/local/lib/python3.10/dist-packages/torch_geometric/data/in_memory_dataset.py:157: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
# lsh_nodes:
# din=1433
# num_functions=1
# ...

# %%
# !python -m tst.ogb.main_with_pruning_node_prediction --dataset Cora --gnn gcn --pruning_method minhash_lsh_thresholding --device 0 \
--num_minhash_funcs 15 --epochs 50
# Out:
# 2023-06-08 16:35:02.273986: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-08 16:35:03.643145: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Getting dataset...
# Dataset ready!
# /usr/local/lib/python3.10/dist-packages/torch_geometric/data/in_memory_dataset.py:157: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
# lsh_nodes:
# din=1433
# num_functions=15
# ...

# %%
# !python -m tst.ogb.main_with_pruning_node_prediction --dataset PubMed --gnn gcn --pruning_method minhash_lsh_thresholding --device 0 \
--num_minhash_funcs 1 --epochs 500
# Out:
# 2023-06-08 16:38:11.982696: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-08 16:38:12.895245: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Getting dataset...
# Dataset ready!
# /usr/local/lib/python3.10/dist-packages/torch_geometric/data/in_memory_dataset.py:157: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
# lsh_nodes:
# din=500
# num_functions=1
# ...

# %%
# !python -m tst.ogb.main_with_pruning_node_prediction --dataset PubMed --gnn gcn --pruning_method minhash_lsh_thresholding --device 0 \
--num_minhash_funcs 3 --epochs 500
# Out:
# 2023-06-08 16:39:42.897228: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-08 16:39:43.810500: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Getting dataset...
# Dataset ready!
# /usr/local/lib/python3.10/dist-packages/torch_geometric/data/in_memory_dataset.py:157: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
# lsh_nodes:
# din=500
# num_functions=3
# ...

# %%
# !python -m tst.ogb.main_with_pruning_node_prediction --dataset PubMed --gnn gcn --pruning_method minhash_lsh_thresholding --device 0 \
--num_minhash_funcs 10 --epochs 500
# Out:
# 2023-06-08 16:42:21.577356: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-08 16:42:22.906137: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Getting dataset...
# Dataset ready!
# /usr/local/lib/python3.10/dist-packages/torch_geometric/data/in_memory_dataset.py:157: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
# lsh_nodes:
# din=500
# num_functions=10
# ...
